# %%
import pandas as pd

# %%
df = pd.read_csv('transaction_data_version2.csv')

# %%
df
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0                 2375  26984851472    1     1004906         1         1.39
# 1                 1929  27021022215    4     1004906         1         1.39
# 2                  568  27021090189    4     1004906         1         1.39
# 3                  887  27031467254    5     1004906         1         1.39
# 4                  175  27057508267    7     1004906         1         1.99
# ...                ...          ...  ...         ...       ...          ...
# 2551702           1598  42305362535  711       92130         1         0.99
# 2551703           1598  42305362535  711      114102         1         8.89
# 2551704           1598  42305362535  711      133449         1         6.99
# 2551705           1598  42305362535  711     6923644         1         4.50
# 2551706           1598  42305362535  711    14055192         1         6.99
#
# ...

# %%
def time_trans(i):
    if len(str(i)) ==4:
        return str(i)[0:2]
    elif len(str(i)) ==3:
        return(str(i)[0])
    elif len(str(i)) ==2:
        return(str(0))
    elif len(str(i)) ==1:
        return(str(i))

# %%
df['hour'] = df.TRANS_TIME.map(time_trans)

# %%
df.head()
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           1929  27021022215    4     1004906         1         1.39
# 2            568  27021090189    4     1004906         1         1.39
# 3            887  27031467254    5     1004906         1         1.39
# 4            175  27057508267    7     1004906         1         1.99
#
#    STORE_ID  TRANS_TIME  WEEK_NO        DATE  MEMBER hour
# 0       364        1631        1  2019-07-30       0   16
# 1       441        1755        1  2019-08-02       1   17
# 2       446          35        1  2019-08-02       0    0
# 3       298        1551        1  2019-08-03       0   15
# 4       446        2303        2  2019-08-05       0   23

# %%
import datetime as dt

# %%
df['hour_time'] = pd.to_datetime(df['hour'],format= '%H' ).dt.time

# %%
df
# Out:
#          household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0                 2375  26984851472    1     1004906         1         1.39
# 1                 1929  27021022215    4     1004906         1         1.39
# 2                  568  27021090189    4     1004906         1         1.39
# 3                  887  27031467254    5     1004906         1         1.39
# 4                  175  27057508267    7     1004906         1         1.99
# ...                ...          ...  ...         ...       ...          ...
# 2551702           1598  42305362535  711       92130         1         0.99
# 2551703           1598  42305362535  711      114102         1         8.89
# 2551704           1598  42305362535  711      133449         1         6.99
# 2551705           1598  42305362535  711     6923644         1         4.50
# 2551706           1598  42305362535  711    14055192         1         6.99
#
# ...

# %%
df2 = df[['household_key','MEMBER','BASKET_ID','PRODUCT_ID','QUANTITY','SALES_VALUE','WEEK_NO','DAY','DATE','hour_time']]

# %%
df2.head()
# Out:
#    household_key  MEMBER    BASKET_ID  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           2375       0  26984851472     1004906         1         1.39
# 1           1929       1  27021022215     1004906         1         1.39
# 2            568       0  27021090189     1004906         1         1.39
# 3            887       0  27031467254     1004906         1         1.39
# 4            175       0  27057508267     1004906         1         1.99
#
#    WEEK_NO  DAY        DATE hour_time
# 0        1    1  2019-07-30  16:00:00
# 1        1    4  2019-08-02  17:00:00
# 2        1    4  2019-08-02  00:00:00
# 3        1    5  2019-08-03  15:00:00
# 4        2    7  2019-08-05  23:00:00

# %%
df2.to_csv('transaction_data_version3.csv',index = False)

# %%
df3 = pd.read_csv('transaction_data_version3.csv')
df3
# Out:
#          household_key  MEMBER    BASKET_ID  PRODUCT_ID  QUANTITY  \
# 0                 2375       0  26984851472     1004906         1
# 1                 1929       1  27021022215     1004906         1
# 2                  568       0  27021090189     1004906         1
# 3                  887       0  27031467254     1004906         1
# 4                  175       0  27057508267     1004906         1
# ...                ...     ...          ...         ...       ...
# 2551702           1598       0  42305362535       92130         1
# 2551703           1598       0  42305362535      114102         1
# 2551704           1598       0  42305362535      133449         1
# 2551705           1598       0  42305362535     6923644         1
# 2551706           1598       0  42305362535    14055192         1
#
#          SALES_VALUE  WEEK_NO  DAY        DATE hour_time
# 0               1.39        1    1  2019-07-30  16:00:00
# 1               1.39        1    4  2019-08-02  17:00:00
# ...
